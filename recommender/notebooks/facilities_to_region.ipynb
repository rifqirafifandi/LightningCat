# %%
import json
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

# %%
plan_area = json.load(open("/Users/siwei/dev/LightningCat/dataAndDataCleanup/MasterPlan2019PlanningAreaBoundaryNoSea.processed.geojson"))

# %%
facilities = json.load(open("/Users/siwei/dev/LightningCat/dataAndDataCleanup/facility_data.json"))

# %%
plan_polygon = {}
for plan in plan_area['features']:
    name = plan['properties']['PLN_AREA_N']
    ps = []
    coordinates = plan['geometry']['coordinates'][0]
    if not isinstance(coordinates[0][0], float):
        coordinates = coordinates[0]
    for c in coordinates:
        ps.append((c[1], c[0]))
    plan_polygon[name.lower()] = Polygon(ps)

# %%
facility_map = {}
for fa in facilities:
    p = Point(fa['location'])
    for plan_name, polygon in plan_polygon.items():
        if polygon.contains(p):
            facility_map[fa['name']] = plan_name
            break

# %%
facility_map
# Out:
# {'Clementi Stadium': 'clementi',
#  'Clementi Sports Centre': 'clementi',
#  'Jurong West Sports Centre': 'jurong west',
#  'Kallang Basin Swimming Complex': 'kallang',
#  'Kallang Sports Centre': 'kallang',
#  'Katong Swimming Complex': 'marine parade',
#  'AMK Swimming Complex': 'ang mo kio',
#  'Bishan Sports Centre': 'bishan',
#  'Bukit Batok Swimming Complex': 'bukit batok',
#  'Farrer Park Field and Tennis Centre': 'kallang',
#  'Jalan Besar Sports Centre': 'kallang',
#  'Jurong East Sports Centre': 'jurong east',
#  'Heartbeat@Bedok': 'bedok',
#  'Hougang Sports Centre': 'hougang',
#  'Bukit Gombak Sports Centre': 'bukit batok',
#  'Bedok Stadium': 'bedok',
#  'Burghley Squash and Tennis Centre': 'serangoon',
#  'Choa Chu Kang Sports Centre': 'choa chu kang',
#  'Jurong Stadium': 'jurong west',
#  'Our Tampines Hub - Community Auditorium': 'tampines',
#  'Pasir Ris Sports Centre': 'pasir ris',
#  'Queenstown Sports Centre': 'queenstown',
#  'Sengkang Sports Centre': 'sengkang',
#  'Serangoon Sports Centre': 'serangoon',
#  'Toa Payoh Sports Centre': 'toa payoh',
#  'Woodlands Sports Centre': 'woodlands',
#  'St Wilfrid Sports Centre': 'kallang',
#  'Yio Chu Kang Sports Centre': 'ang mo kio',
#  'Yishun Sports Centre': 'yishun',
#  'Yishun Swimming Complex': 'yishun',
#  'Co Curricular Activities Branch': 'tanglin',
#  'Delta Sports Centre': 'bukit merah',
#  'Enabling Village Gym': 'bukit merah',
#  'Geylang East Swimming Complex': 'geylang',
#  'Geylang Field': 'geylang'}

# %%
json.dump(facility_map, open("../data/facility_map_plan.json", "w"))
